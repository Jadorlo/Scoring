# %% [markdown]
# Bibliothèques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Chargement des différents CSV en Dataframe

# %%
df_data_OG = pd.read_csv(r'..\files\revenus.csv') # Data originales
df_data_V1 = pd.read_csv(r'..\files\data_V1.csv') # Data avec traitement des valeurs manquantes et aberrantes (avec les "?" et Never-Worked regroupées)
df_data_V2 = pd.read_csv(r'..\files\data_V2.csv') # Data avec traitement des valeurs manquantes et aberrantes + regroupements des modalités des variables qualis et classification des variables quantis

# %% [markdown]
# Definition des variables quali / quanti pour l'analyse descriptive

# %%
# Il y a une séparation des listes des variables entre celle pour les Data Originales et les autres car partir des Data V1, les "age" et "hour-per-weeks" sont regroupées en classes d'ages.

# Listes pour le DATA_OG
variables_quali_DATA_OG = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country','hours-per-week','income']
variables_quali_sans_income_DATA_OG = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country',]
variables_quanti_DATA_OG = ['age','capital-gain', 'capital-loss', 'hours-per-week']

# Listes pour les autres DATA
variables_quali = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country','age','hours-per-week','income']
variables_quali_sans_income = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country','age','hours-per-week']
variables_quanti = ['capital-gain', 'capital-loss']

# %% [markdown]
# # 0. Statistiques Descriptives Data Originales

# %% [markdown]
# ### 0.A. Graphiques Variables Qualitatifs

# %%
# Boucle qui itere le processus de création d'un piechart pour chaque variables qualitatives
for col in variables_quali_DATA_OG:
    # Calcul les proportions d'appartitions des modalités dans la variable
    prop_mod = df_data_OG[col].value_counts()
    print(prop_mod)

    # Créer le pie chart
    plt.figure(figsize=(4, 4))
    plt.pie(prop_mod, labels=prop_mod.index, autopct='%1.1f%%', startangle=140)
    plt.title(f"Proportion des modalités de {col}")
    plt.show()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: relationship, dtype: int64
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64
# Male      32650
# Female    16192
# Name: gender, dtype: int64
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# Nicaragua                        49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Hong                             30
# Thailand                         30
# Cambodia                         28
# Trinadad&Tobago                  27
# Laos                             23
# Yugoslavia                       23
# Outlying-US(Guam-USVI-etc)       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: native-country, dtype: int64
# 40    22803
# 50     4246
# 45     2717
# 60     2177
# 35     1937
#       ...
# 69        1
# 87        1
# 94        1
# 82        1
# 79        1
# Name: hours-per-week, Length: 96, dtype: int64
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %% [markdown]
# ### 0.B. Graphiques Variables Quantitatifs

# %%
# Boucle qui itere le processus de création d'une courbe de densité pour chaque variables quantitatives
for variable in variables_quanti_DATA_OG:
    plt.figure(figsize=(8, 5))
    sns.kdeplot(df_data_OG[variable], shade=True)  # shade=True pour colorier sous la courbe
    plt.title(f'Courbe de densité de {variable}')
    plt.xlabel(variable)
    plt.ylabel('Densité')
    plt.show()
# Out:
# C:\Users\theol\AppData\Local\Temp\ipykernel_31068\3187511645.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_data_OG[variable], shade=True)  # shade=True pour colorier sous la courbe
# C:\Users\theol\AppData\Local\Temp\ipykernel_31068\3187511645.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_data_OG[variable], shade=True)  # shade=True pour colorier sous la courbe
# C:\Users\theol\AppData\Local\Temp\ipykernel_31068\3187511645.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_data_OG[variable], shade=True)  # shade=True pour colorier sous la courbe
# C:\Users\theol\AppData\Local\Temp\ipykernel_31068\3187511645.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_data_OG[variable], shade=True)  # shade=True pour colorier sous la courbe

# %% [markdown]
# ### 0.C. Boxplots Variables Quantitatives

# %%
# Boucle qui itere le processus de création de boxplots pour chaque variables quantitatives
for variable in variables_quanti_DATA_OG:
    plt.figure(figsize=(10, 2))
    sns.boxplot(x=df_data_OG[variable])
    plt.xlabel(variable)
    plt.show()

# %% [markdown]
# ### 0.D. Statistiques Bivariées

# %%
# Boucle qui itere le processus de création de diagrammes en barres empilées, de la proportion d'income pour chaque modalités de chaques variables qualitatives
for variable in variables_quali_sans_income_DATA_OG :
    #Calcule la proportion la proportion de >50k et de <=50k d'income
    grouped = df_data_OG.groupby([variable, 'income']).size().unstack()
    percentages = grouped.divide(grouped.sum(axis=1), axis=0) * 100
    print(percentages)

    # Tri de l'affichage des modalités dans l'ordre croissant en fonction du pourcentage de la classe '<=50K'
    percentages['sort'] = percentages['<=50K']
    percentages = percentages.sort_values(by='sort', ascending=False).drop(columns='sort')

    # Création du diagramme
    ax = percentages.plot(kind='barh', stacked=True, color=['#ec5757', '#4fe29d'])
    plt.title('Répartition des revenus (%) en fonction du type de '+ variable )
    plt.ylabel(variable)
    plt.xlabel('Pourcentage (%)')
    plt.legend(title='Income', loc='upper left')
    plt.show()
# Out:
# income                 <=50K       >50K
# workclass
# ?                  90.532333   9.467667
# Federal-gov        60.824022  39.175978
# Local-gov          70.440051  29.559949
# Never-worked      100.000000        NaN
# Private            78.213296  21.786704
# Self-emp-inc       44.660767  55.339233
# Self-emp-not-inc   72.112895  27.887105
# State-gov          73.245835  26.754165
# Without-pay        90.476190   9.523810
# income            <=50K       >50K
# education
# 10th          93.736501   6.263499
# 11th          94.922737   5.077263
# 12th          92.694064   7.305936
# 1st-4th       96.761134   3.238866
# 5th-6th       94.695481   5.304519
# 7th-8th       93.507853   6.492147
# 9th           94.576720   5.423280
# Assoc-acdm    74.203623  25.796377
# Assoc-voc     74.672489  25.327511
# Bachelors     58.716511  41.283489
# Doctorate     27.441077  72.558923
# HS-grad       84.142169  15.857831
# Masters       45.088446  54.911554
# Preschool     98.795181   1.204819
# Prof-school   26.019185  73.980815
# Some-college  81.035117  18.964883
# income                     <=50K       >50K
# marital-status
# Divorced               89.883914  10.116086
# Married-AF-spouse      62.162162  37.837838
# Married-civ-spouse     55.386747  44.613253
# Married-spouse-absent  90.764331   9.235669
# Never-married          95.452007   4.547993
# Separated              93.529412   6.470588
# Widowed                91.567852   8.432148
# income                 <=50K       >50K
# occupation
# ?                  90.566038   9.433962
# Adm-clerical       86.312600  13.687400
# Armed-Forces       66.666667  33.333333
# Craft-repair       77.372382  22.627618
# Exec-managerial    52.218206  47.781794
# Farming-fishing    88.389262  11.610738
# Handlers-cleaners  93.339768   6.660232
# Machine-op-inspct  87.690271  12.309729
# Other-service      95.856185   4.143815
# Priv-house-serv    98.760331   1.239669
# Prof-specialty     54.893065  45.106935
# Protective-serv    68.667345  31.332655
# Sales              73.201308  26.798692
# Tech-support       70.954357  29.045643
# Transport-moving   79.575372  20.424628
# income              <=50K       >50K
# relationship
# Husband         55.132887  44.867113
# Not-in-family   89.859334  10.140666
# Other-relative  96.547145   3.452855
# Own-child       98.535813   1.464187
# Unmarried       93.970732   6.029268
# Wife            53.110253  46.889747
# income                  <=50K       >50K
# race
# Amer-Indian-Eskimo  88.297872  11.702128
# Asian-Pac-Islander  73.074391  26.925609
# Black               87.918890  12.081110
# Other               87.684729  12.315271
# White               74.601312  25.398688
# income      <=50K       >50K
# gender
# Female  89.074852  10.925148
# Male    69.623277  30.376723
# income                           <=50K       >50K
# native-country
# ?                            74.329055  25.670945
# Cambodia                     67.857143  32.142857
# Canada                       65.384615  34.615385
# China                        70.491803  29.508197
# Columbia                     95.294118   4.705882
# Cuba                         75.362319  24.637681
# Dominican-Republic           95.145631   4.854369
# Ecuador                      86.666667  13.333333
# El-Salvador                  92.903226   7.096774
# England                      62.992126  37.007874
# France                       57.894737  42.105263
# Germany                      71.844660  28.155340
# Greece                       63.265306  36.734694
# Guatemala                    96.590909   3.409091
# Haiti                        88.000000  12.000000
# Holand-Netherlands          100.000000        NaN
# Honduras                     90.000000  10.000000
# Hong                         73.333333  26.666667
# Hungary                      68.421053  31.578947
# India                        58.940397  41.059603
# Iran                         62.711864  37.288136
# Ireland                      70.270270  29.729730
# Italy                        67.619048  32.380952
# Jamaica                      85.849057  14.150943
# Japan                        65.217391  34.782609
# Laos                         91.304348   8.695652
# Mexico                       95.057834   4.942166
# Nicaragua                    93.877551   6.122449
# Outlying-US(Guam-USVI-etc)   95.652174   4.347826
# Peru                         91.304348   8.695652
# Philippines                  71.186441  28.813559
# Poland                       80.459770  19.540230
# Portugal                     82.089552  17.910448
# Puerto-Rico                  89.130435  10.869565
# Scotland                     85.714286  14.285714
# South                        82.608696  17.391304
# Taiwan                       60.000000  40.000000
# Thailand                     83.333333  16.666667
# Trinadad&Tobago              92.592593   7.407407
# United-States                75.602300  24.397700
# Vietnam                      91.860465   8.139535
# Yugoslavia                   65.217391  34.782609

# %% [markdown]
# # 1. Statistiques Descriptives Data_V1

# %% [markdown]
# ### 1.A. Graphiques Variables Qualitatifs

# %%
# Boucle qui itere le processus de création d'un piechart pour chaque variables qualitatives
for col in variables_quali:
    # Calcul les proportions d'appartitions des modalités dans la variable
    prop_mod = df_data_V1[col].value_counts()
    print(prop_mod)

    # Créer le pie chart
    plt.figure(figsize=(4, 4))
    plt.pie(prop_mod, labels=prop_mod.index, autopct='%1.1f%%', startangle=140)
    plt.title(f"Proportion des modalités de {col}")
    plt.show()
# Out:
# Private             33307
# Self-emp-not-inc     3796
# Local-gov            3100
# State-gov            1946
# Self-emp-inc         1646
# Federal-gov          1406
# Without-pay            21
# Name: workclass, dtype: int64
# HS-grad         14783
# Some-college     9899
# Bachelors        7570
# Masters          2514
# Assoc-voc        1959
# 11th             1619
# Assoc-acdm       1507
# 10th             1223
# 7th-8th           823
# Prof-school       785
# 9th               676
# 12th              577
# Doctorate         544
# 5th-6th           449
# 1st-4th           222
# Preschool          72
# Name: education, dtype: int64
# Married-civ-spouse       21055
# Never-married            14598
# Divorced                  6297
# Separated                 1411
# Widowed                   1277
# Married-spouse-absent      552
# Married-AF-spouse           32
# Name: marital-status, dtype: int64
# Craft-repair         6020
# Prof-specialty       6008
# Exec-managerial      5984
# Adm-clerical         5540
# Sales                5408
# Other-service        4808
# Machine-op-inspct    2970
# Transport-moving     2316
# Handlers-cleaners    2046
# Farming-fishing      1480
# Tech-support         1420
# Protective-serv       976
# Priv-house-serv       232
# Armed-Forces           14
# Name: occupation, dtype: int64
# Husband           18666
# Not-in-family     11702
# Own-child          6626
# Unmarried          4788
# Wife               2091
# Other-relative     1349
# Name: relationship, dtype: int64
# White                 38903
# Black                  4228
# Asian-Pac-Islander     1303
# Amer-Indian-Eskimo      435
# Other                   353
# Name: race, dtype: int64
# Male      30527
# Female    14695
# Name: gender, dtype: int64
# United-States                 41292
# Mexico                          903
# Philippines                     283
# Germany                         193
# Puerto-Rico                     175
# Canada                          163
# El-Salvador                     147
# India                           147
# Cuba                            133
# England                         119
# China                           113
# Jamaica                         103
# South                           101
# Italy                           100
# Dominican-Republic               97
# Japan                            89
# Guatemala                        86
# Vietnam                          83
# Columbia                         82
# Poland                           81
# Haiti                            69
# Portugal                         62
# Iran                             56
# Taiwan                           55
# Greece                           49
# Nicaragua                        48
# Peru                             45
# Ecuador                          43
# France                           36
# Ireland                          36
# Thailand                         29
# Hong                             28
# Cambodia                         26
# Trinadad&Tobago                  26
# Yugoslavia                       23
# Outlying-US(Guam-USVI-etc)       22
# Laos                             21
# Scotland                         20
# Honduras                         19
# Hungary                          18
# Holand-Netherlands                1
# Name: native-country, dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\theol\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\theol\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\theol\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 4
#       1 # Boucle qui itere le processus de création d'un piechart pour chaque variables qualitatives
#       2 for col in variables_quali:
#       3     # Calcul les proportions d'appartitions des modalités dans la variable
# ----> 4     prop_mod = df_data_V1[col].value_counts()
#       5     print(prop_mod)
#       7     # Créer le pie chart
#
# File c:\Users\theol\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\theol\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'age'

# %% [markdown]
# ### 1.B. Graphiques Variables Quantitatifs

# %%
# Boucle qui itere le processus de création d'une courbe de densité pour chaque variables quantitatives
for variable in variables_quanti:
    plt.figure(figsize=(8, 5))
    sns.kdeplot(df_data_V1[variable], shade=True)  # shade=True pour colorier sous la courbe
    plt.title(f'Courbe de densité de {variable}')
    plt.xlabel(variable)
    plt.ylabel('Densité')
    plt.show()
# Out:
# C:\Users\theol\AppData\Local\Temp\ipykernel_31068\3187511645.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_data_OG[variable], shade=True)  # shade=True pour colorier sous la courbe
# C:\Users\theol\AppData\Local\Temp\ipykernel_31068\3187511645.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_data_OG[variable], shade=True)  # shade=True pour colorier sous la courbe
# C:\Users\theol\AppData\Local\Temp\ipykernel_31068\3187511645.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_data_OG[variable], shade=True)  # shade=True pour colorier sous la courbe
# C:\Users\theol\AppData\Local\Temp\ipykernel_31068\3187511645.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_data_OG[variable], shade=True)  # shade=True pour colorier sous la courbe

# %%
# Boucle qui itere le processus de création de boxplots pour chaque variables quantitatives
for variable in variables_quanti:
    plt.figure(figsize=(10, 2))
    sns.boxplot(x=df_data_V1[variable])
    plt.xlabel(variable)
    plt.show()

# %% [markdown]
# ### 1.C. Statistiques Bivariées

# %%
# Boucle qui itere le processus de création de diagrammes en barres empilées, de la proportion d'income pour chaque modalités de chaques variables qualitatives
for variable in variables_quali_sans_income :
    #Calcule la proportion la proportion de >50k et de <=50k d'income
    grouped = df_data_V1.groupby([variable, 'income']).size().unstack()
    percentages = grouped.divide(grouped.sum(axis=1), axis=0) * 100
    print(percentages)

    # Tri de l'affichage des modalités dans l'ordre croissant en fonction du pourcentage de la classe '<=50K'
    percentages['sort'] = percentages['<=50K']
    percentages = percentages.sort_values(by='sort', ascending=False).drop(columns='sort')

    # Création du diagramme
    ax = percentages.plot(kind='barh', stacked=True, color=['#ec5757', '#4fe29d'])
    plt.title('Répartition des revenus (%) en fonction du type de '+ variable )
    plt.ylabel(variable)
    plt.xlabel('Pourcentage (%)')
    plt.legend(title='Income', loc='upper left')
    plt.show()
# Out:
# income                 <=50K       >50K
# workclass
# ?                  90.532333   9.467667
# Federal-gov        60.824022  39.175978
# Local-gov          70.440051  29.559949
# Never-worked      100.000000        NaN
# Private            78.213296  21.786704
# Self-emp-inc       44.660767  55.339233
# Self-emp-not-inc   72.112895  27.887105
# State-gov          73.245835  26.754165
# Without-pay        90.476190   9.523810
# income            <=50K       >50K
# education
# 10th          93.736501   6.263499
# 11th          94.922737   5.077263
# 12th          92.694064   7.305936
# 1st-4th       96.761134   3.238866
# 5th-6th       94.695481   5.304519
# 7th-8th       93.507853   6.492147
# 9th           94.576720   5.423280
# Assoc-acdm    74.203623  25.796377
# Assoc-voc     74.672489  25.327511
# Bachelors     58.716511  41.283489
# Doctorate     27.441077  72.558923
# HS-grad       84.142169  15.857831
# Masters       45.088446  54.911554
# Preschool     98.795181   1.204819
# Prof-school   26.019185  73.980815
# Some-college  81.035117  18.964883
# income                     <=50K       >50K
# marital-status
# Divorced               89.883914  10.116086
# Married-AF-spouse      62.162162  37.837838
# Married-civ-spouse     55.386747  44.613253
# Married-spouse-absent  90.764331   9.235669
# Never-married          95.452007   4.547993
# Separated              93.529412   6.470588
# Widowed                91.567852   8.432148
# income                 <=50K       >50K
# occupation
# ?                  90.566038   9.433962
# Adm-clerical       86.312600  13.687400
# Armed-Forces       66.666667  33.333333
# Craft-repair       77.372382  22.627618
# Exec-managerial    52.218206  47.781794
# Farming-fishing    88.389262  11.610738
# Handlers-cleaners  93.339768   6.660232
# Machine-op-inspct  87.690271  12.309729
# Other-service      95.856185   4.143815
# Priv-house-serv    98.760331   1.239669
# Prof-specialty     54.893065  45.106935
# Protective-serv    68.667345  31.332655
# Sales              73.201308  26.798692
# Tech-support       70.954357  29.045643
# Transport-moving   79.575372  20.424628
# income              <=50K       >50K
# relationship
# Husband         55.132887  44.867113
# Not-in-family   89.859334  10.140666
# Other-relative  96.547145   3.452855
# Own-child       98.535813   1.464187
# Unmarried       93.970732   6.029268
# Wife            53.110253  46.889747
# income                  <=50K       >50K
# race
# Amer-Indian-Eskimo  88.297872  11.702128
# Asian-Pac-Islander  73.074391  26.925609
# Black               87.918890  12.081110
# Other               87.684729  12.315271
# White               74.601312  25.398688
# income      <=50K       >50K
# gender
# Female  89.074852  10.925148
# Male    69.623277  30.376723
# income                           <=50K       >50K
# native-country
# ?                            74.329055  25.670945
# Cambodia                     67.857143  32.142857
# Canada                       65.384615  34.615385
# China                        70.491803  29.508197
# Columbia                     95.294118   4.705882
# Cuba                         75.362319  24.637681
# Dominican-Republic           95.145631   4.854369
# Ecuador                      86.666667  13.333333
# El-Salvador                  92.903226   7.096774
# England                      62.992126  37.007874
# France                       57.894737  42.105263
# Germany                      71.844660  28.155340
# Greece                       63.265306  36.734694
# Guatemala                    96.590909   3.409091
# Haiti                        88.000000  12.000000
# Holand-Netherlands          100.000000        NaN
# Honduras                     90.000000  10.000000
# Hong                         73.333333  26.666667
# Hungary                      68.421053  31.578947
# India                        58.940397  41.059603
# Iran                         62.711864  37.288136
# Ireland                      70.270270  29.729730
# Italy                        67.619048  32.380952
# Jamaica                      85.849057  14.150943
# Japan                        65.217391  34.782609
# Laos                         91.304348   8.695652
# Mexico                       95.057834   4.942166
# Nicaragua                    93.877551   6.122449
# Outlying-US(Guam-USVI-etc)   95.652174   4.347826
# Peru                         91.304348   8.695652
# Philippines                  71.186441  28.813559
# Poland                       80.459770  19.540230
# Portugal                     82.089552  17.910448
# Puerto-Rico                  89.130435  10.869565
# Scotland                     85.714286  14.285714
# South                        82.608696  17.391304
# Taiwan                       60.000000  40.000000
# Thailand                     83.333333  16.666667
# Trinadad&Tobago              92.592593   7.407407
# United-States                75.602300  24.397700
# Vietnam                      91.860465   8.139535
# Yugoslavia                   65.217391  34.782609

# %% [markdown]
# # 2. Statistiques Descriptives Data_V2

# %% [markdown]
# ### 2.A. Graphiques Variables Qualitatifs

# %%
# Boucle qui itere le processus de création d'un piechart pour chaque variables qualitatives
for col in variables_quali:
    # Calcul les proportions d'appartitions des modalités dans la variable
    prop_mod = df_data_V2[col].value_counts()
    print(prop_mod)

    # Créer le pie chart
    plt.figure(figsize=(4, 4))
    plt.pie(prop_mod, labels=prop_mod.index, autopct='%1.1f%%', startangle=140)
    plt.title(f"Proportion des modalités de {col}")
    plt.show()
# Out:
# Private                 33906
# State-Local-gov          5117
# Self-emp-not-inc         3862
# No_income_or_unknown     2830
# Self-emp-inc             1695
# Federal-gov              1432
# Name: workclass, dtype: int64
# HS-grad          15784
# Some-college     10878
# Bachelors         8025
# Low-education     6408
# Assoc             3662
# Masters           2657
# Graduation        1428
# Name: education, dtype: int64
# Married-civ-spouse    22379
# Never-married         16117
# Alone                 10346
# Name: marital-status, dtype: int64
# Occupation:VeryHigh-income    12258
# Occupation:Low-income         10123
# Occupation:Very-Low-income    10046
# Occupation:Mid-income          8467
# Occupation:High-income         7948
# Name: occupation, dtype: int64
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: relationship, dtype: int64
# White         41762
# Black          4685
# Other_race     2395
# Name: race, dtype: int64
# Male      32650
# Female    16192
# Name: gender, dtype: int64
# United-States    43832
# Other_country     5010
# Name: native-country, dtype: int64
# (40.0, 57.0]      15078
# (33.0, 40.0]       8925
# (16.999, 23.0]     7226
# (28.0, 33.0]       6414
# (23.0, 28.0]       6066
# (57.0, 90.0]       5133
# Name: age, dtype: int64
# (37.0, 43.0]     24204
# (43.0, 52.0]      8518
# (0.999, 25.0]     5913
# (52.0, 99.0]      5210
# (25.0, 37.0]      4997
# Name: hours-per-week, dtype: int64
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %% [markdown]
# ### 2.B. Graphiques Variables Quantitatifs

# %%
# Boucle qui itere le processus de création d'une courbe de densité pour chaque variables quantitatives
for variable in variables_quanti:
    plt.figure(figsize=(8, 5))
    sns.kdeplot(df_data_V2[variable], shade=True)  # shade=True pour colorier sous la courbe
    plt.title(f'Courbe de densité de {variable}')
    plt.xlabel(variable)
    plt.ylabel('Densité')
    plt.show()
# Out:
# C:\Users\theol\AppData\Local\Temp\ipykernel_31068\52803997.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_data_V2[variable], shade=True)  # shade=True pour colorier sous la courbe
# C:\Users\theol\AppData\Local\Temp\ipykernel_31068\52803997.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_data_V2[variable], shade=True)  # shade=True pour colorier sous la courbe

# %%
# Boucle qui itere le processus de création de boxplots pour chaque variables quantitatives
for variable in variables_quanti:
    plt.figure(figsize=(10, 2))
    sns.boxplot(x=df_data_V1[variable])
    plt.xlabel(variable)
    plt.show()

# %% [markdown]
# ### 2.C. Statistiques Bivariées

# %%
# Boucle qui itere le processus de création de diagrammes en barres empilées, de la proportion d'income pour chaque modalités de chaques variables qualitatives
for variable in variables_quali_sans_income :
    #Calcule la proportion la proportion de >50k et de <=50k d'income
    grouped = df_data_V2.groupby([variable, 'income']).size().unstack()
    percentages = grouped.divide(grouped.sum(axis=1), axis=0) * 100
    print(percentages)

    # Tri de l'affichage des modalités dans l'ordre croissant en fonction du pourcentage de la classe '<=50K'
    percentages['sort'] = percentages['<=50K']
    percentages = percentages.sort_values(by='sort', ascending=False).drop(columns='sort')

    # Création du diagramme
    ax = percentages.plot(kind='barh', stacked=True, color=['#ec5757', '#4fe29d'])
    plt.title('Répartition des revenus (%) en fonction du type de '+ variable )
    plt.ylabel(variable)
    plt.xlabel('Pourcentage (%)')
    plt.legend(title='Income', loc='upper left')
    plt.show()
# Out:
# income                    <=50K       >50K
# workclass
# Federal-gov           60.824022  39.175978
# No_income_or_unknown  90.565371   9.434629
# Private               78.213296  21.786704
# Self-emp-inc          44.660767  55.339233
# Self-emp-not-inc      72.112895  27.887105
# State-Local-gov       71.526285  28.473715
# income             <=50K       >50K
# education
# Assoc          74.467504  25.532496
# Bachelors      58.716511  41.283489
# Graduation     26.610644  73.389356
# HS-grad        84.142169  15.857831
# Low-education  94.288390   5.711610
# Masters        45.088446  54.911554
# Some-college   81.035117  18.964883
# income                  <=50K       >50K
# marital-status
# Alone               90.624396   9.375604
# Married-civ-spouse  55.386747  44.613253
# Never-married       95.452007   4.547993
# income                          <=50K       >50K
# occupation
# Occupation:High-income      72.219426  27.780574
# Occupation:Low-income       87.029537  12.970463
# Occupation:Mid-income       77.985119  22.014881
# Occupation:Very-Low-income  93.927932   6.072068
# Occupation:VeryHigh-income  53.565019  46.434981
# income              <=50K       >50K
# relationship
# Husband         55.132887  44.867113
# Not-in-family   89.859334  10.140666
# Other-relative  96.547145   3.452855
# Own-child       98.535813   1.464187
# Unmarried       93.970732   6.029268
# Wife            53.110253  46.889747
# income          <=50K       >50K
# race
# Black       87.918890  12.081110
# Other_race  78.538622  21.461378
# White       74.601312  25.398688
# income      <=50K       >50K
# gender
# Female  89.074852  10.925148
# Male    69.623277  30.376723
# income              <=50K       >50K
# native-country
# Other_country   80.179641  19.820359
# United-States   75.602300  24.397700
# income              <=50K       >50K
# age
# (16.999, 23.0]  99.321893   0.678107
# (23.0, 28.0]    91.773821   8.226179
# (28.0, 33.0]    79.638291  20.361709
# (33.0, 40.0]    69.221289  30.778711
# (40.0, 57.0]    62.090463  37.909537
# (57.0, 90.0]    73.309955  26.690045
# income              <=50K       >50K
# hours-per-week
# (0.999, 25.0]   93.336716   6.663284
# (25.0, 37.0]    88.773264  11.226736
# (37.0, 43.0]    78.656420  21.343580
# (43.0, 52.0]    59.896689  40.103311
# (52.0, 99.0]    58.733205  41.266795
